# %%
# First import the Dataset
import pandas as pd
data = pd.read_csv("C:/Users/Daniel/Documents/Masterarbeit/documents_text_included_new.csv", encoding="utf-8")
data = data.fillna(method="ffill")

# %%
# Import the Packages
from entitynetwork.enititynetwork_pipeline.process_article import *
from entitynetwork.database_creation.fill_database import *

# %%
# Establishe DB Connection

g = connect_database()

# %%
all_tag = ["B-PERSON", "I-PERSON", "B-NORP", "B-FAC", "I-FAC", "B-ORG", "I-ORG", "B-GPE", "I-GPE",
          "B-LOC", "I-LOC", "B-PRODUCT", "I-PRODUCT", "B-EVENT", "I-EVENT", "B-WORK_OF_ART", "I-WORK_OF_ART",
          "B-LAW", "I-LAW", "B-LANGUAGE", "I-LANGUAGE", "B-DATE", "I-DATE", "B-TIME", "I-TIME", "B-PERCENT",
           "I-PERCENT", "B-MONEY", "I-MONEY", "B-QUANTITY", "I-QUANTITY", "B-ORDINAL", "I-ORDINAL", "B-CARDINAL",
          "I_CARDINAL"]

selected_tag = ["B-PERSON", "I-PERSON", "B-NORP", "B-FAC", "I-FAC", "B-ORG", "I-ORG", "B-GPE", "I-GPE",
          "B-LOC", "I-LOC", "B-PRODUCT", "I-PRODUCT", "B-EVENT", "I-EVENT", "B-WORK_OF_ART", "I-WORK_OF_ART",
          "B-LAW", "I-LAW", "B-LANGUAGE", "I-LANGUAGE"]

# %%
validation_data = pd.read_csv("C:/Users/Daniel/Documents/Masterarbeit/entity_dataframe_lowercase.csv",encoding="utf-8")
#validation_data = validation_data.fillna(method="ffill")

# %%
relation_validation_data = pd.read_csv("C:/Users/Daniel/Documents/Masterarbeit/relation_dataframe_lowercase.csv",encoding="utf-8")

# %%
ent_val = validation_data[validation_data["text_id"]==data["id"][274]]
rel_val = relation_validation_data[relation_validation_data["text_id"]==data["id"][274]]
test = Article(data["text"][274], data["author_extracted"][274], data["date"][274], data["source"][274], data["id"][274],
               download_model=False, selected_tags=selected_tag,graph=g,
               validate=True, entity_validation_data= ent_val,
               relation_validation_data = rel_val)

# %%
test.process_articles()
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Daniel\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Daniel\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package perluniprops to
# [nltk_data]     C:\Users\Daniel\AppData\Roaming\nltk_data...
# [nltk_data]   Package perluniprops is already up-to-date!
# [nltk_data] Downloading package nonbreaking_prefixes to
# [nltk_data]     C:\Users\Daniel\AppData\Roaming\nltk_data...
# [nltk_data]   Package nonbreaking_prefixes is already up-to-date!
# 2020-06-20 01:15:05.272 INFO in 'deeppavlov.core.data.simple_vocab'['simple_vocab'] at line 115: [loading vocabulary from C:\Users\Daniel\.deeppavlov\models\ner_ontonotes_bert_mult\tag.dict]
# 2020-06-20 01:15:43.631 INFO in 'deeppavlov.core.models.tf_model'['tf_model'] at line 51: [loading model from C:\Users\Daniel\.deeppavlov\models\ner_ontonotes_bert_mult\model]
# C:\Users\Daniel\Documents\Masterarbeit\CSS_Termpaper\EntityNetwork\entitynetwork\validation_tool\entity_validation.py:39: FutureWarning: The 'get_values' method is deprecated and will be removed in a future version. Use '.values' or 'np.asarray(..)' instead.
#   duplicate_row = pd.DataFrame(article.entity_validation_data).get_values()[i]
# C:\Users\Daniel\Documents\Masterarbeit\CSS_Termpaper\EntityNetwork\entitynetwork\validation_tool\entity_validation.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.merged_data["synonyms"][~self.merged_data["synonyms"].str.contains("__", na=False)] = np.NaN
# I: 0
# chatham and aylesford mp
# J: 0
# ['sunday express']
# J: 1
# ['parliamentary answer']
# J: 2
# ["england's"]
# J: 3
# ['east sussex']
# J: 4
# ['lancashire']
# J: 5
# ['nottinghamshire']
# J: 6
# ['eric appleby']
# J: 7
# ['alcohol concern']
# J: 8
# ['tracey crouch']
# J: 9
# ['chatham']
# J: 10
# ['aylesford']
# J: 11
# ['department of health']
# J: 12
# ['government']
# I: 1
# eric appleby
# J: 0
# ['sunday express']
# J: 1
# ['parliamentary answer']
# J: 2
# ["england's"]
# J: 3
# ['east sussex']
# J: 4
# ['lancashire']
# J: 5
# ['nottinghamshire']
# J: 6
# ['eric appleby']
# J: 7
# ['alcohol concern']
# J: 8
# ['tracey crouch']
# J: 9
# ['chatham']
# J: 10
# ['aylesford']
# J: 11
# ['department of health']
# J: 12
# ['government']
# I: 2
# mp
# J: 0
# ['sunday express']
# J: 1
# ['parliamentary answer']
# J: 2
# ["england's"]
# J: 3
# ['east sussex']
# J: 4
# ['lancashire']
# J: 5
# ['nottinghamshire']
# J: 6
# ['eric appleby']
# J: 7
# ['alcohol concern']
# J: 8
# ['tracey crouch']
# J: 9
# ['chatham']
# J: 10
# ['aylesford']
# J: 11
# ['department of health']
# J: 12
# ['government']
# I: 3
# parliamentary
# J: 0
# ['sunday express']
# J: 1
# ['parliamentary answer']
# J: 2
# ["england's"]
# J: 3
# ['east sussex']
# J: 4
# ['lancashire']
# J: 5
# ['nottinghamshire']
# J: 6
# ['eric appleby']
# J: 7
# ['alcohol concern']
# J: 8
# ['tracey crouch']
# J: 9
# ['chatham']
# J: 10
# ['aylesford']
# J: 11
# ['department of health']
# J: 12
# ['government']
# I: 4
# the sunday express
# J: 0
# ['sunday express']
# J: 1
# ['parliamentary answer']
# J: 2
# ["england's"]
# J: 3
# ['east sussex']
# J: 4
# ['lancashire']
# J: 5
# ['nottinghamshire']
# J: 6
# ['eric appleby']
# J: 7
# ['alcohol concern']
# J: 8
# ['tracey crouch']
# J: 9
# ['chatham']
# J: 10
# ['aylesford']
# J: 11
# ['department of health']
# J: 12
# ['government']
# I: 5
# tracey crouch
# J: 0
# ['sunday express']
# J: 1
# ['parliamentary answer']
# J: 2
# ["england's"]
# J: 3
# ['east sussex']
# J: 4
# ['lancashire']
# J: 5
# ['nottinghamshire']
# J: 6
# ['eric appleby']
# J: 7
# ['alcohol concern']
# J: 8
# ['tracey crouch']
# J: 9
# ['chatham']
# J: 10
# ['aylesford']
# J: 11
# ['department of health']
# J: 12
# ['government']
# I: 6
# minimum prices for alcohol
# J: 0
# ['sunday express']
# J: 1
# ['parliamentary answer']
# J: 2
# ["england's"]
# J: 3
# ['east sussex']
# J: 4
# ['lancashire']
# J: 5
# ['nottinghamshire']
# J: 6
# ['eric appleby']
# J: 7
# ['alcohol concern']
# J: 8
# ['tracey crouch']
# J: 9
# ['chatham']
# J: 10
# ['aylesford']
# J: 11
# ['department of health']
# J: 12
# ['government']
# I: 7
# alcohol concern
# J: 0
# ['sunday express']
# J: 1
# ['parliamentary answer']
# J: 2
# ["england's"]
# J: 3
# ['east sussex']
# J: 4
# ['lancashire']
# J: 5
# ['nottinghamshire']
# J: 6
# ['eric appleby']
# J: 7
# ['alcohol concern']
# J: 8
# ['tracey crouch']
# J: 9
# ['chatham']
# J: 10
# ['aylesford']
# J: 11
# ['department of health']
# J: 12
# ['government']
# I: 8
# conservative
# J: 0
# ['sunday express']
# J: 1
# ['parliamentary answer']
# J: 2
# ["england's"]
# J: 3
# ['east sussex']
# J: 4
# ['lancashire']
# J: 5
# ['nottinghamshire']
# J: 6
# ['eric appleby']
# J: 7
# ['alcohol concern']
# J: 8
# ['tracey crouch']
# J: 9
# ['chatham']
# J: 10
# ['aylesford']
# J: 11
# ['department of health']
# J: 12
# ['government']
# I: 9
# department of health
# J: 0
# ['sunday express']
# J: 1
# ['parliamentary answer']
# J: 2
# ["england's"]
# J: 3
# ['east sussex']
# J: 4
# ['lancashire']
# J: 5
# ['nottinghamshire']
# J: 6
# ['eric appleby']
# J: 7
# ['alcohol concern']
# J: 8
# ['tracey crouch']
# J: 9
# ['chatham']
# J: 10
# ['aylesford']
# J: 11
# ['department of health']
# J: 12
# ['government']
# I: 10
# government
# J: 0
# ['sunday express']
# J: 1
# ['parliamentary answer']
# J: 2
# ["england's"]
# J: 3
# ['east sussex']
# J: 4
# ['lancashire']
# J: 5
# ['nottinghamshire']
# J: 6
# ['eric appleby']
# J: 7
# ['alcohol concern']
# J: 8
# ['tracey crouch']
# J: 9
# ['chatham']
# J: 10
# ['aylesford']
# J: 11
# ['department of health']
# J: 12
# ['government']
# [9, 10, 6, 13, 1, 0, 8, 14, 7, 15, 11, 12]
# [5, 6, 7, 8, 3]

# %%
test.entity_dataset.df
# Out:
#                     name          tag count    weight                synonyms
# 0         sunday express          ORG     1  1.000000        _sunday express_
# 1   parliamentary answer  WORK_OF_ART     1  0.869565  _parliamentary answer_
# 2              england's          GPE     1  0.826087             _england's_
# 3            east sussex          GPE     1  0.739130           _east sussex_
# 4             lancashire          GPE     1  0.739130            _lancashire_
# 5        nottinghamshire          GPE     1  0.739130       _nottinghamshire_
# 6           eric appleby       PERSON     1  0.565217          _eric appleby_
# 7        alcohol concern          ORG     1  0.565217       _alcohol concern_
# 8          tracey crouch       PERSON     1  0.347826         _tracey crouch_
# 9                chatham       PERSON     1  0.217391               _chatham_
# 10             aylesford       PERSON     1  0.217391             _aylesford_
# 11  department of health          ORG     1  0.130435  _department of health_
# 12            government          ORG     1  0.086957            _government_

# %%
test.entity_validation_data
# Out:
#                         entity    lable count  \
# 0     chatham and aylesford mp    addne     2
# 0     chatham and aylesford mp    addne     2
# 1                 eric appleby    addne     1
# 2                           mp    addne     1
# 3                parliamentary    addne     1
# 4           the sunday express    addne     1
# 5                tracey crouch    addne     2
# 6   minimum prices for alcohol  concept     1
# 7              alcohol concern    relne     1
# 8                 conservative    relne     1
# 9         department of health    relne     1
# 10                  government    relne     1
#
#                                     synonym text_id
# 0   chatham and aylesford mp__tracey crouch     276
# 0   chatham and aylesford mp__tracey crouch     276
# 1                                        na     276
# 2                                        na     276
# 3                                        na     276
# 4                                        na     276
# 5   chatham and aylesford mp__tracey crouch     276
# 6                                        na     276
# 7                                        na     276
# 8                                        na     276
# 9                                        na     276
# 10                                       na     276

# %%
test.relation_validation.metrics_df
# Out:
#    found_relations  missed_relations  false_positives  accuracy  recall  \
# 0              1.0               4.0              4.0  0.111111     0.2
#
#    precision   f1
# 0        0.2  0.2

# %%
test.entity_validation.metrics_df
#temp = temp.get_values()[0]
# Out:
#    found_entities  missed_entities  false_positives  accuracy  recall  \
# 0             9.0              3.0              4.0    0.5625    0.75
#
#    precision    f1
# 0   0.692308  0.72

# %%
test.entity_validation.merged_data
# Out:
#                          name     tag count_x    weight synonyms  \
# 0                     england     GPE       4         1       na
# 1                     english    NORP       1         1       na
# 2        sheffield university     ORG       2  0.941176       na
# 3              bbc's panorama     ORG       1  0.941176       na
# 3              bbc's panorama     ORG       1  0.941176       na
# 4                    scotland     GPE       2  0.705882       na
# 5   scotch whisky association     ORG       1  0.705882       na
# 6               david cameron  PERSON       1  0.647059       na
# 7                 home office     ORG       1  0.529412       na
# 8                     commons     ORG       1  0.411765       na
# 9             alcohol concern     ORG       1  0.352941       na
# 10               eric appleby  PERSON       1  0.176471       na
# 11                         na      na      na        na       na
# 12                         na      na      na        na       na
# 13                         na      na      na        na       na
# 14                         na      na      na        na       na
# 15                         na      na      na        na       na
# 16                         na      na      na        na       na
# 17                         na      na      na        na       na
# 18                         na      na      na        na       na
# 19                         na      na      na        na       na
#
#                                      entity    lable count_y  \
# 0                                        na       na      na
# 1                                        na       na      na
# 2                      sheffield university    relne       2
# 3                                       bbc    addne       1
# 3                                  panorama    addne       1
# 4                                        na       na      na
# 5                 scotch whisky association    relne       1
# 6                             david cameron    addne       1
# 7                               home office    relne       1
# 8           commons health select committee    relne       1
# 9                           alcohol concern    relne       1
# 10                             eric appleby    addne       1
# 11             50p - a - unit minimum price  concept       8
# 12                            minimum price  concept       8
# 13  minimum price for alcohol at 50p a unit  concept       8
# 14                          minimum pricing  concept       8
# 15           minimum unit price for alcohol  concept       8
# 16                        unit price at 50p  concept       8
# 17                                coalition    relne       2
# 18                               government    relne       2
# 19                minimum unit price at 50p    relne       8
#
#                                               synonym text_id
# 0                                                  na      na
# 1                                                  na      na
# 2                                sheffield university     272
# 3                                                  na     272
# 3                                                  na     272
# 4                                                  na      na
# 5                                                  na     272
# 6                                                  na     272
# 7                                                  na     272
# 8                                                  na     272
# 9                                                  na     272
# 10                                                 na     272
# 11  minimum price for alcohol at 50p a unit__minim...     272
# 12  minimum price for alcohol at 50p a unit__minim...     272
# 13  minimum price for alcohol at 50p a unit__minim...     272
# 14  minimum price for alcohol at 50p a unit__minim...     272
# 15  minimum price for alcohol at 50p a unit__minim...     272
# 16  minimum price for alcohol at 50p a unit__minim...     272
# 17                              coalition__government     272
# 18                              coalition__government     272
# 19  minimum price for alcohol at 50p a unit__minim...     272

# %%
columns = ["found_entities","missed_entities","additional_entities","accuracy","recall","precision","f1"]
metrics = np.array([test.entity_validation.found_entities,
          test.entity_validation.missed_entities,
          test.entity_validation.false_positives,
          test.entity_validation.accuracy,
          test.entity_validation.recall,
          test.entity_validation.precision,
          test.entity_validation.f1])
pd.DataFrame(metrics.reshape(-1,len(metrics)),columns=columns)
# Out:
#    found_entities  missed_entities  additional_entities  accuracy    recall  \
# 0            10.0              2.0                  1.0  0.769231  0.833333
#
#    precision        f1
# 0   0.909091  0.869565

# %%
test.entity_validation.metrics_df.columns
# Out:
# Index(['found_entities', 'missed_entities', 'false_positives', 'accuracy',
#        'recall', 'precision', 'f1'],
#       dtype='object')

# %%
relation_metrics = pd.DataFrame(columns=["found_relations", "missed_relations", "false_positives", "accuracy",
                                         "recall", "precision", "f1"])

relation_metrics
# Out:
# Empty DataFrame
# Columns: [found_relations, missed_relations, false_positives, accuracy, recall, precision, f1]
# Index: []

# %%
relation_metrics.append(test.relation_validation.metrics_df)
# Out:
#    found_relations  missed_relations  false_positives  accuracy  recall  \
# 0              1.0               4.0              4.0  0.111111     0.2
#
#    precision   f1
# 0        0.2  0.2

# %%
# load the necessary data
import pandas as pd
data = pd.read_csv("/home/ubuntu/ma_project/mup_valid_articles.csv", encoding="utf-8")
validation_data = pd.read_csv("/home/ubuntu/ma_project/entity_dataframe_lowercase.csv",encoding="utf-8")
relation_validation_data = pd.read_csv("/home/ubuntu/ma_project/relation_dataframe_lowercase.csv",encoding="utf-8")
initial_nodes = pd.read_csv("/home/ubuntu/ma_project/MUP_nodes.csv",sep = ";", encoding="utf-8")

# %%
# load the functionalities
from entitynetwork.enititynetwork_pipeline.process_article import *
from entitynetwork.database_creation.fill_database import *
from entitynetwork.relation_extraction.relation_extraction import *
from allennlp.predictors.predictor import Predictor
#from entitynetwork.validation_tool.relation_validation import *

# %%
# Establishe DB Connection
global g
g = connect_database(db_name = "testimprovements")

# %%
constituency_predictor_1 = Predictor.from_path("https://storage.googleapis.com/allennlp-public-models/elmo-constituency-parser-2020.02.10.tar.gz")

# %%
initial_entities_dict, initial_entities_df = create_synonym_dict(g, None)
global_start = time.time()
for i in range(15, 20):
    print("Current Article" + str(i))
    #ent_val = validation_data[validation_data["text_id"]==data["id"][i]]
    #rel_val = relation_validation_data[relation_validation_data["text_id"]==data["id"][i]]
    article = Article(data["text"][i], data["author_extracted"][i], data["date"][i], data["source"][i], data["id"][i],
               download_ner_model=True, n_shift=0,graph=g,first_round=False ,commit=True,
               initial_entities = initial_entities_df,initial_syn_dict = initial_entities_dict,
                validate=False, filter_by_constituency=True,use_coref = False,
                     path_constituency_parser="/home/ubuntu/ma_project/elmo-constituency-parser-2020.02.10.tar.gz",
                     path_coref_parser="/home/ubuntu/ma_project/coref-spanbert-large-2020.02.27.tar.gz",
                     constituency_predictor = constituency_predictor_1)
    article.process_articles()
global_stop = time.time()
print("time for last quater articles: ", global_stop-global_start)
# Out:
# Current Article15
# Relation Extraction: 0.2613520622253418
# constituency took:  5.148960590362549
# constituency took:  5.4979777336120605
# constituency took:  5.521806001663208
# constituency took:  5.801554918289185
# Filter Relations: 5.839418649673462
# __ArticleNode: 0.0004982948303222656
# __Publuischer: 0.00022363662719726562
# __Author: 0.00018978118896484375
# __push article_node: 0.014021158218383789
# __push author_node: 0.0030350685119628906
# __push publisher_node: 0.0029256343841552734
# __commit_relationships: 8.283554792404175
# __calculate_sub_graph_metrics: 0.2322225570678711
# Commit to db: 8.537807941436768
# Current Article16
# Relation Extraction: 0.3152344226837158
# constituency took:  5.498833179473877
# constituency took:  5.830776691436768
# constituency took:  6.194553852081299
# constituency took:  6.73885178565979
# Filter Relations: 6.816039562225342
# __ArticleNode: 0.0003998279571533203
# __Publuischer: 6.4849853515625e-05
# __Author: 0.00011467933654785156
# __push article_node: 0.00585174560546875
# __push author_node: 0.002865314483642578
# __push publisher_node: 0.0028290748596191406
# __commit_relationships: 0.5548839569091797
# __calculate_sub_graph_metrics: 0.21837711334228516
# Commit to db: 0.7861344814300537
# Current Article17
# Relation Extraction: 0.37357044219970703
# constituency took:  8.495700120925903
# constituency took:  9.83119797706604
# constituency took:  11.342193603515625
# constituency took:  12.315964698791504
# Filter Relations: 12.441329002380371
# __ArticleNode: 0.0004591941833496094
# __Publuischer: 0.00020742416381835938
# __Author: 0.00010323524475097656
# __push article_node: 0.005650520324707031
# __push author_node: 0.003340005874633789
# __push publisher_node: 0.0031342506408691406
# __commit_relationships: 1.0257935523986816
# __calculate_sub_graph_metrics: 0.1349174976348877
# Commit to db: 1.1749825477600098
# Current Article18
# Relation Extraction: 0.17420196533203125
# constituency took:  2.1875836849212646
# constituency took:  2.4322290420532227
# constituency took:  2.891711711883545
# constituency took:  3.703397512435913
# Filter Relations: 3.9320342540740967
# __ArticleNode: 0.0005862712860107422
# __Publuischer: 0.0001761913299560547
# __Author: 0.00011849403381347656
# __push article_node: 0.005978107452392578
# __push author_node: 0.003772735595703125
# __push publisher_node: 0.0032432079315185547
# __commit_relationships: 0.4275672435760498
# __calculate_sub_graph_metrics: 0.14125728607177734
# Commit to db: 0.5838255882263184
# Current Article19
# Relation Extraction: 0.38976478576660156
# constituency took:  8.416536092758179
# constituency took:  9.854343891143799
# constituency took:  10.839555740356445
# constituency took:  10.938069581985474
# Filter Relations: 11.029021739959717
# __ArticleNode: 0.0003490447998046875
# __Publuischer: 8.940696716308594e-05
# __Author: 0.00011324882507324219
# __push article_node: 0.01174783706665039
# __push author_node: 0.0032231807708740234
# __push publisher_node: 0.002850770950317383
# __commit_relationships: 0.5261414051055908
# __calculate_sub_graph_metrics: 0.15259552001953125
# Commit to db: 0.6979002952575684
# time for last quater articles:  53.54576253890991
